# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('vgsales-12-4-2019.csv')

# %%
# Relationship between Publisher and sales/shipped

# %%
>>> df["Publisher_Sales"] = df.groupby(["Publisher"])["Global_Sales"].transform(sum)

# %%
df.head(50)
# Out:
#     Rank                                          Name             Genre  \
# 0      1                                    Wii Sports            Sports
# 1      2                             Super Mario Bros.          Platform
# 2      3                                Mario Kart Wii            Racing
# 3      4                 PlayerUnknown's Battlegrounds           Shooter
# 4      5                             Wii Sports Resort            Sports
# 5      6            Pokemon Red / Green / Blue Version      Role-Playing
# 6      7                         New Super Mario Bros.          Platform
# 7      8                                        Tetris            Puzzle
# 8      9                     New Super Mario Bros. Wii          Platform
# 9     10                                     Minecraft              Misc
# 10    11                                     Duck Hunt           Shooter
# 11    12                                      Wii Play              Misc
# ...

# %%
# number of games made, including repeats across platforms.
df['Publisher'].value_counts()
# Out:
# Unknown                4891
# Sega                   2085
# Activision             1519
# Ubisoft                1519
# Electronic Arts        1498
#                        ...
# SCEE                      1
# Conifer Games             1
# BigBrik Games             1
# Playrix                   1
# State of Play Games       1
# Name: Publisher, Length: 3069, dtype: int64
